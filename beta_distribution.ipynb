# %%
import numpy
import pandas
from matplotlib import pyplot
from scipy.stats import norm, binom, beta
import math
import json

# %%
x_ax = numpy.linspace(0, 1, 1000)

# %%
a_ = 2
b_ = 5
pds = beta.pdf(x_ax, a_, b_)

# %%
pyplot.figure(figsize=(9,6))
pyplot.plot(x_ax, pds)
# pyplot.plot(x_ax, pds, '.')
# pyplot.vlines(x_ax, 0, pds)

# %%
numpy.dot(x_ax, pds) / len(x_ax)
# Out:
# 0.2854285714275684

# %%
pds.sum() / len(x_ax)
# Out:
# 0.9989974974990018

# %%
a_ / (a_ + b_)
# Out:
# 0.2857142857142857

# %%
pyplot.figure(figsize=(9,6))
pyplot.plot(x_ax, beta.pdf(x_ax, 3, 9))
pyplot.plot(x_ax, beta.pdf(x_ax, 50, 20))
